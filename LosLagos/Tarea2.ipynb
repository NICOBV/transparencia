# %% [markdown]
# # Tarea 2 : scraper
# **Marcel Carl Esteban Jaure Trujillo**

# %%
from time import sleep
from selenium import webdriver
import random
import pandas as pd
import sqlite3, datetime
import os   
from datetime import datetime

# %%
log_file = "loslagos.log"
if not os.path.isfile(log_file):
    open(log_file, 'w+')

driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU233/PR/PCONT/50090665')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertomonttcontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
    
csv.close()
driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU233/PR/PPLANT/50086097')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertomonttplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU036/PR/PCONT/50575667')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="chaitencontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU036/PR/PPLANT/50576176')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="chaitenplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU191/PR/PCONT/48516321')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="osornocontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU191/PR/PPLANT/50080497')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="osornoplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU095/PR/PCONT/50036100')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="futaleufucontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU095/PR/PPLANT/50036475')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="futaleufuplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU142/PR/PCONT/44838167')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="llanquihuecontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU142/PR/PPLANT/44794444')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="llanquihueplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU235/PR/PPLANT/50322569')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertooctaycontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU235/PR/PPLANT/50322569')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertooctayplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU236/PR/PCONT/50876979')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertovarascontrata.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU236/PR/PPLANT/50878477')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertovarasplanta.csv"
csv=open(df,"w")
titulor="Año , Mes , Estamento , Nombre completo , Cargo o función , Grado EUS / Cargo con jornada , Calificación profesional o formación , Región , Asignaciones especiales , Unidad monetaria , Remuneración bruta mensualizada , Remuneración líquida mensualizada , Montos y horas extraordinarias diurnas , Montos y horas extraordinarias nocturnas , Montos y horas extraordinarias festivas , Fecha de inicio dd/mm/aa , Fecha de término dd/mm/aa , Declaración de intereses y patrimonio (publicación por buena práctica) , Viáticos , Observaciones\n"
csv.write(titulor)
i=0
for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+","
    if i==20:
        dato = dato+"\n"
        i=0
    csv.write(dato) 
    i=i+1
    print(dato)
csv.close()

now = datetime.now()
date = now.strftime("%d_%m_%Y")
time = now.strftime('%H:%M:%S.%f')[:-3] 
mensaje ="PuertoMontt-Chaiten-Osorno-Futaleufu-Llanquihue-PuertoOctay-PuertoVaras "
full_mensaje = time + ' | ' + mensaje + date + '\n'
file = open(log_file, 'a+')
file.write(full_mensaje)
# Out:
# 2021,
# Mayo,
# Técnico,
# CARCAMO FONSECA, ALEJANDRA E.,
# ADMINISTRATIVO DIDECO,
# 10,
# Tecnico Forestal,
# Región de Los Lagos,
# (150)(149)(01),
# Pesos,
# 1.986.775,
# 1.638.686,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2021,
#
# Mayo,
# Técnico,
# MACHU VENEGONI, MARIANNE SIM,
# APOYO TECNICO DE OPERACIONES,
# 14,
# tecnico en construccion,
# Región de Los Lagos,
# (150)(149)(01),
# Pesos,
# 1.192.974,
# 992.948,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ABALOS VILLAR, DANTE MATIAS,
# PROFESIONAL DEPARTAMENTO DE PERSONAL,
# 14,
# educacion media,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.353.529,
# 1.124.379,
# No tiene,
# No tiene,
# No tiene,
# 04/11/2019,
# 31/12/2020,
# No publica,
# No informa,
# Contrata a contar de Mayo 2020,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILA GONZALEZ, SANDRA L.,
# ADMINISTRATIVO DIRECCION DE OBRAS,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.354.100,
# 1.123.687,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILA OJEDA, PABLO ANDRES,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.214.419,
# 1.008.244,
# No tiene,
# No tiene,
# $96.534 : 31,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# AGUILA PAREDES, FRANCISCO AN,
# AUXILIAR DIRECCION DE ASEO Y ORNATO,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.015.864,
# 849.093,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# 173.127,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILAR CANIPANE, VICTOR,
# INPECTOR DIRECCION DE ASEO Y ORNATO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.161.634,
# 972.903,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# AGUILAR CARCAMO, JUAN,
# AUXILIAR DEPARTAMENTO DE MANTENIMIENTO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.158.264,
# 963.678,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILAR HERNANDEZ, ALEX RODRIGO,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.217.486,
# 1.012.298,
# No tiene,
# No tiene,
# $43.596 : 14,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# AGUILAR MOLINA, PEDRO PATRIC,
# AUXILIAR DEPARTAMENTO ELECTRICO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.158.264,
# 963.678,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILAR VELASQUEZ, JEANNETTE,
# ADMINISTRATIVO 1ER JUZGADO POLICIA LOCAL,
# 16,
# tec. Adm. Gestion municipal,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.202.074,
# 1.001.953,
# No tiene,
# No tiene,
# $117.400 : 40,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# AGUILERA LOAIZA, JHONATHAN GA,
# AUXILIAR DESARROLLO COMUNITARIO,
# 18,
# educacion tecnico profesional,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.004.437,
# 833.769,
# $60.450 : 30,00hrs,
# No tiene,
# $87.084 : 36,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ALMONACID OYARZUN, SONIA GEOVAN,
# PROFESIONAL DELEGACION MUNICIPAL ALERCE,
# 11,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 2.152.158,
# 1.737.884,
# No tiene,
# No tiene,
# $252.648 : 44,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ALMONACID ROJEL, NELSON RUBEN,
# ADMINISTRATIVO DIRECCION DE OBRAS,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (150)(149)(01),
# Pesos,
# 1.025.941,
# 855.947,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ALMONACID SERON, PABLO MAURIC,
# ADMINISTRATIVO 3ER JUZGADO DE POLICIA LOCAL,
# 18,
# ingeniero ejecucion adm empresas,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.009.497,
# 848.790,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# ALTAMIRANO ALTAMIRANO, PAULINA A.,
# ADMINISTRATIVO ADM. MUNICIPAL,
# 10,
# tecnico en turismo,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.209.139,
# 1.816.491,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ALTAMIRANO GALLARDO, PEDRO FELIPE,
# PROFESIONAL DEPTO. PERSONAL,
# 10,
# ingeniero administracion de empresas,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.513.094,
# 2.037.017,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ALTAMIRANO MILLANERI, YVANIA CONST,
# ADMINISTRATIVO DEPTO LICITACIONES,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.353.529,
# 1.124.379,
# No tiene,
# No tiene,
# No tiene,
# 02/09/2019,
# 28/02/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ALVARADO SERON, CAROLINA IRI,
# PROFESIONAL DE PERSONAL,
# 12,
# Administrador Publico,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.005.339,
# 1.643.351,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# ALVAREZ CONTRERAS, CRISTIAN LOR,
# ALCALDIA,
# 13,
# enseñanza media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.519.162,
# 1.262.567,
# No tiene,
# No tiene,
# No tiene,
# 02/09/2019,
# 28/02/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ALVAREZ DIAZ, NESTOR FABIAN,
# PROFESIONAL LICITACIONES,
# 11,
# ingeniero comercial,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.145.802,
# 1.750.594,
# No tiene,
# No tiene,
# No tiene,
# 16/09/2019,
# 15/03/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# AMPUERO CARDENAS, CHRISTIAN A.,
# APOYO TECNICO SECPLAN,
# 13,
# tecnico en administracion,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.529.551,
# 1.262.880,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AMPUERO HERNANDEZ, DANITZA BELE,
# ADMINISTRATIVO 1ER JUZGADO POLICIA LOCAL,
# 16,
# tecnico asistente judicial,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.164.185,
# 975.454,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ANTECAO AGUILA, CARLOS FERNA,
# PROFESIONAL SECPLAN,
# 11,
# constructor civil,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.145.873,
# 1.750.487,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# ARAUZ PARDO, TANIA,
# TECNICO DELEGACION ALERCE,
# 12,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.759.874,
# 1.450.557,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ARAVENA MALDONADO, LIDER EMMANU,
# PROFESIONAL DIRECCION DE OPERACIONES,
# 12,
# Ingeniero en prevencion de riesgos,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.001.949,
# 1.648.438,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ARAYA CATALAN, ASTRID ESTEF,
# ASESORIA JURIDICA,
# 9,
# abogado,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 2.911.834,
# 2.392.261,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# ARAYA TOLEDO, DANIELA DEL,
# ENCARGADA BUTAPUCHE,
# 12,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.006.492,
# 1.641.354,
# No tiene,
# No tiene,
# No tiene,
# 01/09/2019,
# 28/02/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# ARISMENDI GALLE, ORLANDO ANDR,
# PROFESIONAL DEPARTAMENTO DE CONTABILIDAD,
# 12,
# ingeniero comercial,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.561.100,
# 1.288.867,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# 31/01/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AROS ALTAMIRANO, CESAR PATRIC,
# INSPECTOR MUNICIPAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.139.775,
# 1.052.679,
# No tiene,
# No tiene,
# $152.620 : 52,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# 19.237,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# ASENCIO MANSILLA, JOSE HUMBERT,
# AUXILIAR DIRECCION DE OBRAS,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.008.894,
# 843.082,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# 402.920,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ASENCIO SOTO, NADIA PAULIN,
# ADMINISTRATIVO DEPARTAMENTO DE PERSONAL,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.355.036,
# 1.122.556,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# ASENCIO VARGAS, JESSICA,
# ADMINISTRATIVO DIRECCION JURIDICA,
# 12,
# tecnico asistente judicial,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.635.285,
# 1.352.993,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2019,
# 31/03/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# AYANCAN BONTES, RODRIGO,
# ADMINISTRATIVO 3ER JUZGADO DE POLICIA LOCAL,
# 16,
# profesor,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.164.680,
# 969.255,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BAHAMONDE ESPANA, VERONICA,
# PROFESIONAL DEPTO. LICITACIONES,
# 11,
# ingeniero administracion de empresas,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.145.802,
# 1.750.594,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIA SCHENKE, JUAN CARLOS,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.215.732,
# 1.003.814,
# No tiene,
# No tiene,
# $168.156 : 54,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIA SCHENKE, TAMARA A.,
# ADMINISTRATIVO DIRECCION DE OBRAS MUNICIPALES,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.166.424,
# 972.771,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# BARRIENTOS BARRIENTOS, VIVIANA YANET,
# SECRETARIA GABINETE ALCALDIA,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.325.600,
# 1.100.137,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2019,
# 31/03/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIENTOS GALLARDO, EVELYN NICOL,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.215.732,
# 1.006.928,
# No tiene,
# No tiene,
# $90.306 : 29,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIENTOS OJEDA, MARCOS DANIE,
# INSPECTOR MUNICIPAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.207.183,
# 1.001.698,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIENTOS OYARZO, JULIO RAUL,
# ADMINISTRATIVO DIRECCION DE OBRAS,
# 12,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.782.134,
# 1.342.005,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIENTOS VARGAS, CRISTIAN,
# ENCARGADO OFICINA DIRECCION ASEO Y ORNATO,
# 12,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.773.900,
# 1.461.562,
# $128.000 : 32,00hrs,
# No tiene,
# $244.800 : 51,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# 327.029,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BECERRA GALLARDO, EDUARDO,
# PROFESIONAL DEPARTAMENTO ELECTRICO,
# 12,
# ingeniero electrico,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.006.492,
# 1.641.354,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BECERRA RUIZ, FABIAN A.,
# TECNICO DIDECO (SEGURIDAD PUBLICA),
# 9,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 2.918.015,
# 2.395.386,
# No tiene,
# No tiene,
# $174.405 : 21,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BELLO BAHAMONDES, MIXSY A.,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 11,
# tecnico acuicola,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.874.633,
# 1.540.785,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BENAVIDES SALDIVIA, MARIO ALBERT,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.215.732,
# 1.005.558,
# No tiene,
# No tiene,
# $124.560 : 40,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BENITEZ PARADA, JUAN CARLOS,
# DELEGADO MUNICIPAL,
# 7,
# asistente social,
# Región de Los Lagos,
# (150)(33),
# Pesos,
# 3.222.305,
# 2.660.718,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BERRIOS JORQUERA, CECILIA ALEJ,
# ADMINISTRATIVO ALCALDIA,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.354.100,
# 1.123.687,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# 384.740,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BISSETT POSTLER, DINA BEATRIZ,
# PROFESIONAL DIDECO,
# 12,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.006.492,
# 1.641.354,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2019,
# 31/03/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BOHLE JORQUERA, CARLOS ANDRE,
# ADMINISTRATIVO DELEGACION FRESIA CARDONAL L.,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.160.830,
# 968.260,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# BOHLE SEGOVIA, JOSE LUIS,
# DEPARTAMENTO ELECTRICO,
# 17,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.061.689,
# 885.994,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BORQUEZ GUERRERO, RAUL,
# PROFESIONAL SECPLAN,
# 11,
# ingeniero computacion,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 2.152.158,
# 1.758.096,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# BUSTAMANTE MAYORGA, YANET VALESK,
# PROFESIONAL SECPLAN,
# 8,
# arquitecto,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 3.363.354,
# 2.800.818,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# BUSTAMANTE PEREZ, GLORIA DEL P,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.167.231,
# 969.693,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# 519.399,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# BUSTAMANTE REYES, JOAQUIN M,
# AUXILIAR SECPLAN,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.004.476,
# 839.624,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# CALDERON LAVADOS, NANCY PAOLA,
# ADMINISTRATIVO 1ER JUZGADO POLICIA LOCAL,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(33),
# Pesos,
# 1.367.059,
# 1.131.970,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# CALDERON MENDEZ, ROSA,
# ADMINISTRATIVO ALCALDIA,
# 13,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.522.071,
# 1.259.008,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# CALISTRO VALDERAS, HELIA ANDREA,
# ADMINISTRATIVO 1ER JUZGADO POLICIA LOCAL,
# 16,
# tecnico asistente judicial,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.167.231,
# 971.806,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# CALIXTO HERNANDEZ, ANGELICA,
# ADMINISTRATIVO DEPARTAMENTO DE PERSONAL,
# 12,
# ingeniero en adm. De empresas,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.006.559,
# 1.641.247,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# CARCAMO BALCAZAR, HERNALDO LUC,
# AUXILIAR DIRECCION DE OBRAS,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.155.218,
# 967.300,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# CARCAMO NAVARRO, RENE LUIS,
# SECRETARIA MUNICIPAL,
# 16,
# ingeniero civil,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.162.085,
# 966.759,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# CARCAMO SERON, JOSE MANUEL,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.215.777,
# 1.010.482,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# CARDENAS CARDENAS, CLAUDIA A.,
# TECNICO SUBDIRECCION DE RENTAS,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.164.680,
# 969.255,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# CARDENAS GARCIA, ANA MARIA,
# ADMINISTRATIVO DIDECO,
# 12,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.768.040,
# 1.454.652,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# CASANOVA PINOCHET, LUIS FERNAND,
# INSPECTOR MUNICIPAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(33),
# Pesos,
# 1.212.329,
# 1.015.785,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# CASTRO ABURTO, HECTOR ELIAS,
# PROFESIONAL DIDECO,
# 10,
# ingeniero en admministarcion,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.514.620,
# 2.034.780,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2019,
# 31/03/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# CATALAN MUNOZ, CESAR HERNAN,
# AUXILIAR SUBDIRECCION COMUNITARIA (DIDECO),
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.007.750,
# 839.782,
# $40.300 : 20,00hrs,
# No tiene,
# $21.771 : 9,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# CATALAN VILLANUEVA, RICHARD H.,
# AUXILIAR DIRECCION DE ASEO Y ORNATO,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.023.595,
# 851.191,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# CERDA MARTINEZ, PATRICIO ALE,
# PROFESIONAL DIDECO,
# 12,
# ingeniero informatico,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.006.559,
# 1.640.287,
# No tiene,
# No tiene,
# $24.000 : 5,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# CHAVEZ CHAVEZ, JOSE LUIS,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 13,
# tecnico en construccion,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.523.118,
# 1.257.726,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# CID TORREJON, PABLO IGNACI,
# PROFESIONAL DIRECCION DE OBRAS,
# 11,
# arquitecto,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 2.148.575,
# 1.763.445,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# CIFUENTES HERNANDEZ, RICHARD ANTONIO,
# PROFESIONAL CONTROL,
# 12,
# educacion profesional,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.005.339,
# 1.643.151,
# No tiene,
# No tiene,
# No tiene,
# 21/10/2019,
# 20/04/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# COLGUAN COLGUAN, FRANCISCO JA,
# AUXILIAR CHOFER ALCALDIA,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(33),
# Pesos,
# 1.011.406,
# 840.068,
# $36.270 : 18,00hrs,
# No tiene,
# $104.017 : 43,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# CONTRERAS ARAYA, CAMILA JAZMI,
# PROFESIONAL DEPARTAMENTO ELECTRICO,
# 12,
# ingeniero en electricidad,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.006.492,
# 1.641.354,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# CRUZ OLAVARRIA, ROCIO VICTOR,
# TECNICO DIRECCION DE OBRAS,
# 15,
# constructor civil,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.218.158,
# 1.018.681,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# DELGADO DURAN, RENE SERGIO,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.142.816,
# 1.056.694,
# No tiene,
# No tiene,
# $21.798 : 7,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# DELGADO OYARZO, PABLO IGNACI,
# ADMINISTRATIVO TURISMO,
# 14,
# Tecnico en Turismo,
# Región de Los Lagos,
# (150)(149)(01),
# Pesos,
# 1.164.384,
# 966.851,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# DELGADO RIOS, RAUL ALEJAND,
# AUXILIAR DIRECCION DE ASEO Y ORNATO,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 1.013.279,
# 849.003,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# DIAZ GODOY, SILVANA C.,
# ADMINISTRATIVO DIRECCION DE OPERACIONES,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.161.634,
# 972.903,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# DIAZ HERNANDEZ, JORGE EDUARD,
# ADMINISTRATIVO ALCALDIA,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.162.129,
# 961.655,
# No tiene,
# No tiene,
# No tiene,
# 01/09/2019,
# 28/02/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# DIAZ MORALES, FRANCIA I.,
# ADMINISTRACION MUNICIPAL,
# 16,
# tecnico asistente judicial,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.164.636,
# 969.310,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# DIAZ RUIZ, SUSANA A.,
# ADMINISTRATIVO DEPTO. CALLES Y CAMINOS,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.163.873,
# 970.220,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# DIETZ ARAUZ, MARTA GALINA,
# JEFE DEPARTAMENTO PERSONAL,
# 7,
# ingeniero administracion publica,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 3.962.212,
# 3.300.539,
# No tiene,
# No tiene,
# No tiene,
# 14/11/2019,
# 31/05/2020,
# No publica,
# No informa,
# Contrata a contar de Mayo 2020,
# 2020,
#
# Mayo,
# Administrativo,
# DONOSO SANTANA, RAUL ALBERTO,
# ADMINISTRATIVO ALCALDIA,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.523.118,
# 1.257.726,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# 31/08/2020,
# No publica,
# No informa,
# Contrata a contar de Mayo 2020,
# 2020,
#
# Mayo,
# Profesional,
# ELGUETA CATALAN, JORGE EDUARD,
# PROFESIONAL ALCALDIA,
# 10,
# periodista,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.514.535,
# 1.973.596,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# 31/08/2020,
# No publica,
# No informa,
# Contrata a contar de Mayo 2020,
# 2020,
#
# Mayo,
# Profesional,
# ESPINEIRA HIGUEIRA, VALERIA YANI,
# PROFESIONAL DIRECCION DE OBRAS,
# 11,
# arquitecto,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.141.001,
# 1.757.715,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ESPINOZA ROMAN, LORENA MARIB,
# SECRETARIA CONCEJAL,
# 16,
# Tecnico en Comunicación Audiovisual,
# Región de Los Lagos,
# (150)(149)(01),
# Pesos,
# 1.022.430,
# 854.964,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# ESPINOZA SANCHEZ, RUTH I.,
# ADMINISTRATIVA LEY DEL LOBBY,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.355.036,
# 1.122.556,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# FARFAN ROSALES, SONIA FABIOL,
# ADMINISTRACION MUNICIPAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.162.085,
# 966.759,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Auxiliar,
# FERNANDEZ AGUILERA, ALEJANDRO MA,
# AUXILIAR DELEGACION ALERCE,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(41)(33),
# Pesos,
# 1.009.539,
# 842.934,
# No tiene,
# No tiene,
# $45.961 : 19,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# FUENTES ORTIZ, SANDRA JUDIT,
# JEFE DEPARTAMENTO SUBDIRECCION SOCIAL,
# 11,
# asistente social,
# Región de Los Lagos,
# (151)(150)(149)(33),
# Pesos,
# 2.160.951,
# 1.759.665,
# No tiene,
# No tiene,
# $28.710 : 5,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# GAETE BASCUÑAN, OCTABIO ANDRES,
# PROFESIONAL ASEO Y ORNATO,
# 9,
# sociologo,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 2.904.631,
# 2.385.765,
# No tiene,
# No tiene,
# No tiene,
# 16/09/2019,
# 15/03/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# GALLARDO ALVAREZ, CLAUDIA A.,
# ADMINISTRATIVO DIRECCION DE TRANSITO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.160.771,
# 936.444,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# GALLARDO LEFINIR, JUAN ARMANDO,
# CHOFER RELACIONES PUBLICAS,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.231.032,
# 1.042.301,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# GALLARDO PAVEZ, MANUEL JESUS,
# ADMINISTRATIVO DEPARTAMENTO DE BIENES,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.145.110,
# 953.361,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# 31/01/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Profesional,
# GALLEGOS VIDAL, CRISTABEL NA,
# PROFESIONAL SECPLAN,
# 11,
# Administrador Publico,
# Región de Los Lagos,
# (150)(149)(01),
# Pesos,
# 1.714.399,
# 1.403.346,
# No tiene,
# No tiene,
# No tiene,
# 06/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Técnico,
# GALLEGUILLOS PEREZ, DIEGO EDUARD,
# DEPTO MANTENIMIENTO,
# 16,
# tecnico mecanico,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.169.833,
# 973.289,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# GALLO MUNOZ, DIEGO ALEXIS,
# SECRETARIO CONCEJAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.160.830,
# 968.260,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# GARAY GARAY, VERONICA DEL,
# ADMINISTRATIVO 1ER JUZGADO POLICIA LOCAL,
# 15,
# tecnico asistente judicial,
# Región de Los Lagos,
# (151)(150)(149)(41)(01),
# Pesos,
# 1.220.879,
# 1.015.584,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2020,
#
# Mayo,
# Administrativo,
# GARDAIX ROJAS, JORGE ARIEL,
# ADMINISTRATIVO DESARROLLO COMUNITARIO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (151)(150)(149)(01),
# Pesos,
# 1.218.283,
# 1.006.490,
# No tiene,
# No tiene,
# $165.042 : 53,00hrs,
# 01/01/2020,
# 31/12/2020,
# No publica,
# No informa,
# Sin observaciones,
# 2021,
# Mayo,
# Profesional,
# OJEDA MENDOZA, HECTOR JAVIE,
# PROFESIONAL DIRECCION DE TRANSITO,
# 11,
# administrador publico,
# Región de Los Lagos,
# (01),
# Pesos,
# 1.297.138,
# 1.059.972,
# No tiene,
# No tiene,
# No tiene,
# 01/04/2020,
# 06/07/2022,
# Sin observaciones,
# No publica,
# No informa,
# 2021,
#
# Mayo,
# Auxiliar,
# PEREZ MUNOZ, FROILAN ANTO,
# AUXILIAR CHOFER ASEO Y ORNATO,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (01)(149)(150),
# Pesos,
# 1.006.469,
# 816.187,
# $196.968 : 58,00hrs,
# No tiene,
# $334.150 : 82,00hrs,
# 04/01/2011,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2021,
#
# Mayo,
# Jefatura,
# SANCHEZ CUMIAN, INES DEL CAR,
# PROFESIONAL DELEGACION RURAL,
# 11,
# Administrador de Empresas,
# Región de Los Lagos,
# (01)(149)(150),
# Pesos,
# 1.443.278,
# 1.189.583,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/05/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2021,
#
# Mayo,
# Directivo,
# TRAMON GUARDA, JORGE EDUARD,
# DIRECTIVO DIDECO,
# 9,
# ingeniero comercial,
# Región de Los Lagos,
# (01)(149)(150),
# Pesos,
# 1.945.239,
# 1.769.299,
# No tiene,
# No tiene,
# No tiene,
# 11/02/2020,
# 10/08/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# ABARZA RODRIGUEZ, FERNANDO PATRICIO,
# ADMINISTRATIVO DEPARTAMENTO DE BIENES,
# 12,
# Técnico adm. Control municipal,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.803.106,
# 1.482.107,
# No tiene,
# No tiene,
# No tiene,
# 01/06/2012,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ABURTO MIRANDA, ELIANA MARIA,
# ADMINISTRATIVO DIRECCION CONTROL,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.562.019,
# 1.288.302,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2006,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ACUNA IDE, MAURICIO ANT,
# PROFESIONAL DEPARTAMENTO TESORERIA,
# 12,
# contador auditor,
# Región de Los Lagos,
# (01)(149)(150)(151),
# Pesos,
# 2.001.949,
# 1.648.438,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/05/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# AGUERO AVENDANO, INGRID LORETO,
# CAJERO DEPARTAMENTO TESORERIA,
# 10,
# tecnico en administracion,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.229.737,
# 1.823.956,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2009,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILA ABURTO, MARIA DEL CARMEN,
# OPERADOR TELEFONICO CENTRAL,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.192.997,
# 991.977,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# AGUILA AGUILA, JORGE LUIS,
# BODEGUERO DELEGACION ALERCE,
# 14,
# agente comercial,
# Región de Los Lagos,
# (01)(149)(150)(151),
# Pesos,
# 1.355.036,
# 1.122.556,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/05/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# AGUILA ZUNIGA, IVAN ARMANDO,
# TECNICO DIDECO,
# 9,
# contador general,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.699.279,
# 2.202.456,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1994,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# AGUILAR CARMONA, JOSE JORGE,
# TECNICO EN DEPARTAMENTO ELECTRICO,
# 9,
# tecnico electromecanico,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.705.171,
# 2.213.786,
# No tiene,
# No tiene,
# No tiene,
# 01/07/1983,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# AGUILAR OJEDA, LUIS ORLANDO,
# CHOFER DIDECO,
# 13,
# educacion media laboral,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.615.650,
# 1.330.168,
# No tiene,
# No tiene,
# No tiene,
# 01/04/1978,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILAR URIBE, MIGUEL ANGEL,
# DEPARTAMENTO DE ANALISIS Y REVISION D. CONTROL,
# 12,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.838.239,
# 1.509.473,
# No tiene,
# No tiene,
# No tiene,
# 15/05/1990,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILAR VARGAS, ROSA A.,
# ADMINISTRATIVO 2DO JUZGADO POLICIA LOCAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.130.801,
# 1.045.943,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILERA BARRIENTOS, FLORIANA,
# DIRECCION JURIDICA,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.555.585,
# 1.283.144,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2019,
# 31/03/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# AGUILERA BARRIENTOS, TOMAS GASTON,
# CHOFER DIDECO (AMPLIFICACION),
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.569.517,
# 1.299.462,
# No tiene,
# No tiene,
# No tiene,
# 01/05/1997,
# 31/12/2999,
# Sin observaciones,
# No publica,
# 654.054,
# 2020,
#
# Mayo,
# Profesional,
# ALARCON FLORES, HUGO ALBERTO,
# PROFESIONAL SUBDIRECCION DE RENTAS,
# 9,
# ingeniero gestion de empresas,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.926.302,
# 2.380.177,
# $89.973 : 13,00hrs,
# No tiene,
# $274.065 : 33,00hrs,
# 04/01/2011,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ALARCON GALLARDO, PABLO GUSTAVO,
# JEFE DEPARTAMENTO LICITACIONES,
# 8,
# ingeniero agroindustrial,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 3.365.439,
# 2.735.224,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2017,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Jefatura,
# ALFARO VELASQUEZ, MARGARITA,
# JEFATURA EN SECRETARIA MUNICIPAL,
# 9,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.862.087,
# 2.352.653,
# No tiene,
# No tiene,
# No tiene,
# 01/07/1979,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ALMONACID ALMONACID, MARIA P.,
# ADMINISTRATIVA DEPTO CONTABILIDAD,
# 14,
# tecnico en administracion,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.385.094,
# 1.146.088,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ALMONACID PAREDES, CLAUDIA ANDREA,
# PROFESIONAL DIRECCION DE OBRAS,
# 8,
# constructor civil,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 3.396.593,
# 2.816.994,
# No tiene,
# No tiene,
# No tiene,
# 09/07/2008,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ALMONACID PAREDES, MARIO EDUARDO,
# PROFESIONAL DIDECO,
# 6,
# asistente social,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.884.364,
# 4.024.743,
# No tiene,
# No tiene,
# No tiene,
# 16/10/1989,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# ALTAMIRANO MILLANERI, PRISCILA IVONNE,
# ADMINISTRATIVO DEPARTAMENTO DE PERSONAL,
# 11,
# educacion tecnico profesional,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.889.711,
# 1.552.734,
# No tiene,
# No tiene,
# $74.646 : 13,00hrs,
# 15/01/2016,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ALTAMIRANO ORTEGA, TANIA,
# PROFESIONAL DIDECO,
# 7,
# asistente social,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.085.874,
# 3.408.161,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1994,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ALTAMIRANO RIFFO, JESSICA ARIELA,
# CAJERO DEPARTAMENTO TESORERIA,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(40)(149)(150)(151),
# Pesos,
# 1.601.040,
# 1.318.730,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2011,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ALVARADO ALVAREZ, CRISTIAN ALEXIS,
# AUXILIAR DIRECCION DE OPERACIONES,
# 15,
# educacion basica completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.223.850,
# 1.017.450,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2018,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ALVARADO ANGEL, JUAN ALBERTO,
# AUXILIAR DIRECCION OPERACIONES CALLES Y CAMINOS,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.392.608,
# 1.151.970,
# No tiene,
# No tiene,
# No tiene,
# 10/04/2015,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# ALVARADO CORTES, BERTA,
# ADMINISTRATIVO DEPTO. ANALISIS DIR. CONTROL,
# 11,
# Técnico adm. Control municipal,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.668.465,
# 1.375.243,
# No tiene,
# No tiene,
# No tiene,
# 01/09/2019,
# 28/02/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ALVARADO RIVERA, VICTOR HUGO,
# AUXILIAR CHOFER DEPARTAMENTO DE VIVIENDA,
# 14,
# educacion media laboral,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.373.637,
# 1.139.016,
# No tiene,
# No tiene,
# No tiene,
# 01/07/2001,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ALVAREZ AGUERO, VICTOR A.,
# AUXILIAR DIRECCION TRANSITO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.158.264,
# 961.819,
# $46.474 : 19,00hrs,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ALVAREZ BARRIA, ALBERTO EUDILIO,
# AUXILIAR DIRECCION OPERACIONES CALLES Y CAMINOS,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.570.196,
# 1.294.582,
# No tiene,
# No tiene,
# No tiene,
# 01/11/1995,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ALVAREZ MONJE, EDMUNDO ALADINO,
# ADMINISTRATIVO 1ER JUZGADO POLICIA LOCAL,
# 11,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.950.305,
# 1.600.178,
# No tiene,
# No tiene,
# No tiene,
# 01/08/1984,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# AMPUERO ICARTE, TERESITA DEL,
# ADMINISTRATIVO DIRECCION DE OBRAS,
# 14,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.385.094,
# 1.146.088,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# ANAZCO KRAUTZ, LUIS FERNANDO,
# DIRECTIVO DIRECCION JURIDICA,
# 6,
# abogado,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.852.237,
# 3.996.990,
# No tiene,
# No tiene,
# No tiene,
# 01/04/2010,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# ANGULO BARRIA, LEONEL I.,
# TECNICO EN DEPARTAMENTO DE BIENES,
# 13,
# contador general,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.555.525,
# 1.283.216,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ANGULO OELCKERS, RAUL JORGE,
# INSPECTOR MUNICIPAL,
# 11,
# tecnico bibliotecario,
# Región de Los Lagos,
# (30)(33)(40)(149)(150)(151),
# Pesos,
# 1.980.264,
# 1.630.137,
# No tiene,
# No tiene,
# No tiene,
# 01/06/1985,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ARAYA MATUS, DAGOBERTO ENRIQUE,
# PROFESIONAL DEPARTAMENTO ELECTRICO,
# 9,
# ingeniero agroindustrial,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.947.858,
# 2.424.752,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2011,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ARAYA MATUS, LORETO,
# PROFESIONAL SECPLAN,
# 9,
# constructor civil,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.908.724,
# 2.402.641,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# ARCOS ARCOS, MARCELA ALEJANDRA,
# ACTUARIO 3ER JUZGADO POLICIA LOCAL,
# 11,
# secretaria ejecutiva,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.912.505,
# 1.570.434,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1994,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ARIAS MANCILLA, PAULINA GLAD,
# ADMINISTRATIVA SECRETARIA MUNICIPAL,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.169.789,
# 973.344,
# No tiene,
# No tiene,
# No tiene,
# 01/12/2019,
# 31/05/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# AROS RUIZ, HERNAN BALBINO,
# SUBDIRECCION COMUNITARIA DIDECO,
# 11,
# tecnico en construccion,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.889.711,
# 1.493.053,
# $191.400 : 40,00hrs,
# No tiene,
# $625.878 : 109,00hrs,
# 15/01/2016,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ARRIAGADA BERNIER, NATALIA FRAN,
# PROFESIONAL DIRECCION DE OPERACIONES,
# 12,
# ingeniero informacion y control de gestion,
# Región de Los Lagos,
# (01)(149)(150)(151),
# Pesos,
# 2.004.593,
# 1.644.314,
# No tiene,
# No tiene,
# No tiene,
# 01/12/2019,
# 31/05/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ARRIAGADA CARCAMO, VICTOR ALBINO,
# ADMINISTRATIVO SUBDIRECCION SOCIAL DIDECO,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.614.892,
# 1.346.634,
# No tiene,
# No tiene,
# No tiene,
# 28/03/1993,
# 31/12/2999,
# Sin observaciones,
# No publica,
# 96.185,
# 2020,
# Mayo,
# Jefatura,
# ARRIAGADA ESPANA, SERGIO FERNANDO,
# ENCARGADO OFICINA CONTABILIDAD,
# 7,
# contador general,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 3.698.436,
# 3.081.524,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1982,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# ARROYO DATTOLI, ALVARO PATRICIO,
# PROFESIONAL ITO DIRECCION DE OBRAS,
# 8,
# constructor civil,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 3.388.304,
# 2.813.580,
# No tiene,
# No tiene,
# No tiene,
# 28/05/2014,
# 31/12/2999,
# Sin observaciones,
# No publica,
# 283.791,
# 2020,
#
# Mayo,
# Profesional,
# ASENCIO CISTERNA, TATIANA ELIZABETH,
# PROFESIONAL 3ER JUZGADO POLICIA LOCAL,
# 6,
# contador auditor,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.829.226,
# 3.979.272,
# No tiene,
# No tiene,
# No tiene,
# 01/08/1995,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# ASENCIO OYARZUN, MARIA GUILLERMINA,
# ACTUARIO 2DO JUZGADO POLICIA LOCAL,
# 12,
# educacion media completa,
# Región de Los Lagos,
# (33)(41)(149)(150)(151),
# Pesos,
# 1.775.497,
# 1.633.115,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1994,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ASENCIO TOLEDO, ENGELBERTO DIONISIO,
# AUXILIAR DIRECCION DE TRANSITO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.222.735,
# 1.015.930,
# No tiene,
# No tiene,
# No tiene,
# 10/04/2015,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# ASENCIO VERA, JOSE ROBERTO,
# AUXILIAR DEPARTAMENTO OBRAS MENORES,
# 14,
# educacion basica completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.380.532,
# 1.142.622,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2009,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# AZOCAR YUNGE, RICARDO ANTONIO,
# AUXILIAR CHOFER DIDECO,
# 15,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.222.735,
# 1.015.930,
# No tiene,
# No tiene,
# No tiene,
# 10/04/2015,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# BAEZ MENA, XIMENA ANTONIETA,
# ADMINISTRATIVO DEPTO ADMINISTRATIVO DIDECO,
# 11,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.973.099,
# 1.617.871,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1982,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# BAHAMONDE ALMONACID, OSCAR EDUARDO,
# SUBDIRECTOR DE RENTAS,
# 6,
# administrador publico,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.907.375,
# 3.991.576,
# No tiene,
# No tiene,
# No tiene,
# 01/04/1995,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# BAHAMONDE SOTO, GANDY A.,
# ADMINISTRATIVO LICENCIAS DE CONDUCIR,
# 18,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.026.107,
# 857.744,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# BARREAUX LEVICOY, CAROLA A.,
# ADMINISTRATIVO DIRECCION DE TRANSITO,
# 16,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.198.107,
# 996.070,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# BARRIA GOMEZ, JESSICA ARLE,
# PROFESIONAL DIRECCION DE CONTROL,
# 12,
# ingeniero en gestion de empresas,
# Región de Los Lagos,
# (01)(149)(150)(151),
# Pesos,
# 2.006.559,
# 1.641.247,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 31/05/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIA UMANZOR, PATRICIA ALEJANDRA,
# ACTUARIO 3ER JUZGADO POLICIA LOCAL,
# 12,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.703.029,
# 1.560.647,
# No tiene,
# No tiene,
# No tiene,
# 11/02/1994,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# BARRIA VARGAS, EDUARDO HUMBERTO,
# ENCARGADO RECINTO (ADMINISTRACION MUNICIPAL),
# 10,
# tecnico electromecanico,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.229.737,
# 1.823.956,
# No tiene,
# No tiene,
# No tiene,
# 03/01/2000,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# BARRIENTOS ESPINOZA, PAULA A.,
# PRPFESIONAL SECPLAN,
# 7,
# asistente social,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.044.654,
# 3.364.640,
# No tiene,
# No tiene,
# No tiene,
# 01/10/1997,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# BARRIENTOS HERNANDEZ, PATRICIA DEL CARMEN,
# ADMINISTRATIVO 3ER JUZGADO POLICIA LOCAL,
# 13,
# educacion media completa,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.577.603,
# 1.308.702,
# No tiene,
# No tiene,
# No tiene,
# 01/09/1999,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# BARRIENTOS VERA, GABRIELA,
# PROFESINAL SECPLAN,
# 7,
# constructor civil,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 4.034.348,
# 3.359.746,
# No tiene,
# No tiene,
# No tiene,
# 19/02/1996,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# BASTIAS GOMEZ, ANGELA BELSANIA,
# PROFESIONAL DIDECO,
# 5,
# asistente social,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 5.230.840,
# 4.262.176,
# No tiene,
# No tiene,
# No tiene,
# 01/07/1982,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# BENAVIDES ULLOA, GLORIA DEL CARMEN,
# JEFE DEPARTAMENTO TESORERIA,
# 9,
# ingeniero administracion empresas,
# Región de Los Lagos,
# (33)(41)(149)(150)(151),
# Pesos,
# 2.984.148,
# 2.460.830,
# No tiene,
# No tiene,
# No tiene,
# 18/07/1995,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# BENAVIDES ULLOA, JUAN C.,
# ADMINISTRATIVO DEPARTAMENTO ASEO Y ORNATO,
# 18,
# agente comercial,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.021.689,
# 855.085,
# No tiene,
# No tiene,
# No tiene,
# 02/01/2019,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# BERNER KLEIN, CLAUDIO CRISTINO,
# JEFE DEPARTAMENTO DE ESTUDIOS Y PRESUPUESTO,
# 5,
# ingeniero agronomo,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 5.487.932,
# 4.450.747,
# No tiene,
# No tiene,
# No tiene,
# 01/02/1982,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# BOHLE ANTINIRRE, JOSE MANUEL,
# TECNICO EN DEPARTAMENTO ELECTRICO,
# 9,
# tecnico en electronica,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 2.725.679,
# 2.226.948,
# No tiene,
# No tiene,
# No tiene,
# 01/12/1986,
# 31/12/2999,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# BRAVO CARCAMO, ANGELICA MAR,
# PROFESIONAL DIDECO,
# 9,
# sociologo,
# Región de Los Lagos,
# (01)(149)(150),
# Pesos,
# 2.635.221,
# 2.105.367,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2020,
# 30/06/2020,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# BUSTAMANTE AGUERO, JUAN CARLOS,
# AUXILIAR DIRECCION OPERACIONES CALLES Y CAMINOS,
# 13,
# educacion media laboral,
# Región de Los Lagos,
# (33)(149)(150)(151),
# Pesos,
# 1.614.603,
# 1.331.609,
# No tiene,
# No tiene,
# No tiene,
# 06/01/1984,
# ...
# No tiene,
# No tiene,
# No tiene,
# 16/08/2013,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Mansilla Almonacid, Daniel José,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 18,
# Enseñanza Básica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.007.396,
# 836.845,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Mansilla Mansilla, Carolina Patricia,
# SECRETARIA UNIDAD DE TRANSPARENCIA,
# 13,
# Secretaria Contable,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.563.093,
# 1.034.452,
# No tiene,
# No tiene,
# No tiene,
# 01/11/2013,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Mansilla Vargas, Luis Omar,
# CONDUCTOR DE DIDECO,
# 19,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 937.407,
# 590.028,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Mansilla Vasquez, Rodolfo Alfredo,
# ADMINISTRATIVO DE OFICINA DE SUBSIDIOS Y PRESTACIONES MONETARIAS,
# 14,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.219.510,
# 966.043,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Mansilla Zumelzu, Carlos Gerardo,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 13,
# Enseñanza Básica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.677.411,
# 1.341.550,
# No tiene,
# No tiene,
# No tiene,
# 17/12/1973,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Martínez Hernández, José Heriberto,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 16,
# Enseñanza Básica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.181.341,
# 958.944,
# No tiene,
# No tiene,
# No tiene,
# 17/12/2018,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# Matamala Montiel, Bernabe Ricardo,
# DIRECTOR DE OBRAS MUNICIPALES,
# 7,
# Constructor Civil,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 4.260.562,
# 3.335.922,
# No tiene,
# No tiene,
# No tiene,
# 01/06/1988,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Mena Antiman, Karla Cristina,
# ADMTVO. DEL DEPTO. DE TESORERÍA,
# 17,
# Contador General,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 942.609,
# 756.486,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Molina Kappes, Yoselyn Valesca,
# COORDINADORA COMUNAL DE SENDA PREVIENE,
# 13,
# Trabajador Social,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.374.386,
# 1.097.690,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# Morales Gúzman, Karina Paola,
# DIRECTORA DE MEDIO AMBIENTE,
# 8,
# Ingeniero Ambiental,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 3.501.006,
# 2.829.538,
# No tiene,
# No tiene,
# No tiene,
# 01/07/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Muñoz Millalonco, Fidel Segundo,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 15,
# Enseñanza Básica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.231.097,
# 990.178,
# No tiene,
# No tiene,
# No tiene,
# 17/12/2018,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Nail Quintul, Claudio Andrés,
# ENCARGADO DE LICENCIAS DE CONDUCIR,
# 12,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.841.745,
# 1.433.905,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Navarro Hernandez, Paola Andrea,
# SECRETARIA DE DIRECCIÓN DE ADMINISTRACIÓN Y FINANZAS,
# 13,
# Técnico en Hotelería y Turismo,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.376.981,
# 1.084.868,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Navarro Mansilla, Damaris Ivonne,
# APOYO ADMTVO. TESORERÍA,
# 17,
# Contador Nivel Técnico,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.069.066,
# 770.671,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# Niklitschek Horn, Susana Verónica,
# ADMINISTRADORA MUNICIPAL,
# 6,
# Abogada,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 4.375.217,
# 3.638.562,
# No tiene,
# No tiene,
# No tiene,
# 16/09/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Norambuena Kondor, María José,
# ENCARGADA DEL DEPTO. DE FOMENTO PRODUCTIVO,
# 10,
# Médico Veterinario,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 2.541.723,
# 2.053.255,
# No tiene,
# No tiene,
# No tiene,
# 01/07/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Opitz Niklitscheck, Ricardo Jose,
# ADMINISTRATIVO DE DEPTO. DE OPERACIONES,
# 12,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.892.143,
# 1.506.160,
# No tiene,
# No tiene,
# No tiene,
# 16/02/1987,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Orellana Yunge, Ricardo Javier,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 14,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.384.987,
# 1.127.825,
# No tiene,
# No tiene,
# No tiene,
# 01/11/2013,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Oyarzo Godoy, Ricardo Ivan,
# AUXILIAR DEPTO. DE OPERACIONES,
# 13,
# Enseñanza Básica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.610.976,
# 1.121.521,
# No tiene,
# No tiene,
# No tiene,
# 01/10/1989,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Oyarzo Haase, Marcela De Lourdes,
# ASISTENTE SOCIAL DEL DEPTO. SOCIAL,
# 17,
# Asistente Social,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 937.507,
# 684.528,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Oyarzo Mansilla, Juan Carlos,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 13,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.572.275,
# 1.225.450,
# No tiene,
# No tiene,
# No tiene,
# 11/11/2000,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Oyarzún Lemus, Héctor Eduardo,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 16,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.181.385,
# 806.228,
# No tiene,
# No tiene,
# No tiene,
# 17/12/2018,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# Palma Alvarado, Rodrigo Andres,
# DIRECTOR DE CONTROL INTERNO,
# 6,
# Ingeniero Comercial,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 4.868.777,
# 3.496.359,
# No tiene,
# No tiene,
# No tiene,
# 21/01/2014,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Pardo Vera, Marcela Elizabeth,
# SECRETARIO ABOGADO DEL JPL DE PTO. VARAS,
# 9,
# Abogada,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 3.006.561,
# 2.476.468,
# No tiene,
# No tiene,
# No tiene,
# 03/09/2018,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Paredes Oyarzo, Patricia Veronica,
# SECRETARIA DIRECCIÓN DE OBRAS MUNICIPALES,
# 12,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.838.280,
# 1.423.841,
# No tiene,
# No tiene,
# No tiene,
# 14/08/1989,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Paredes Rain, Jeannette Paola,
# APOYO ADMTVO. DEPTO. DE CONTABILIDAD,
# 14,
# Técnico Universitario en Administración de Empresas,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.217.994,
# 891.781,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Paredes Ruíz, Sandra Elizabeth,
# SECRETARIA DEPTO. DE TRANSITO Y TRANSPORTE PÚBLICO,
# 12,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.840.525,
# 1.395.940,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Perez Bravo, Andrea Jacqueline,
# ENCARGADA DE LA OFICINA DEL ADULTO MAYOR,
# 12,
# Asistente Social,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.924.404,
# 1.510.831,
# No tiene,
# No tiene,
# No tiene,
# 04/11/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Perez Guarda, Suly Verena,
# APOYO PROFESIONAL DE DIRECCIÓN DE SEGURIDAD PÚBLICA,
# 12,
# Administrador Público,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.817.716,
# 1.497.979,
# No tiene,
# No tiene,
# No tiene,
# 04/11/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Perez Ojeda, Lorena Alejandra,
# APOYO ADMINISTRATIVO EN JUZGADO DE POLICÍA LOCAL DE PUERTO VARAS,
# 13,
# Técnico Jurídico,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.374.430,
# 1.082.317,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Jefatura,
# Rain Coñecar, Sandra Artemia,
# JEFE DE OFICINA DE PRESUPUESTO,
# 9,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 2.685.928,
# 1.938.709,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1994,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Jefatura,
# Reuter Navarro, Sandra Jacqueline,
# ENCARGADA DE CUENTAS CORRIENTES,
# 12,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.575.606,
# 1.253.035,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Rosas Nail, Yessenia Ivette,
# APOYO ADMTVO. DEPTO. DE CONTABILIDAD,
# 15,
# Secretaria,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.247.768,
# 976.890,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Ruiz Guerrero, Margarita del Carmen,
# ADMINISTRATIVA DE DIRECCIÓN DE OBRAS MUNICIPALES,
# 13,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.564.099,
# 1.199.705,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2006,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Ruiz Martinez, Jose Luis,
# MAYORDOMO,
# 13,
# Enseñanza Básica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.518.293,
# 1.325.962,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2006,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Saldivia Vargas, Norma Angélica,
# ENCARGADA DE RENTAS Y PATENTES,
# 10,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 2.284.347,
# 1.839.721,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Sanchez Gallardo, Jaime Esteban,
# JEFE DE UNIDAD DE COMPRAS PÚBLICAS,
# 12,
# Ingeniero Ejec. Adm. Empresas,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 2.029.884,
# 1.563.599,
# No tiene,
# No tiene,
# No tiene,
# 04/11/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Sandoval Mansilla, Jorge Bladimir,
# INSPECTOR EN CASINO DE JUEGOS,
# 18,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.025.817,
# 716.499,
# No tiene,
# No tiene,
# No tiene,
# 01/01/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Soto Gonzalez, Victor Hugo,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 13,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.551.730,
# 1.143.030,
# No tiene,
# No tiene,
# No tiene,
# 01/11/2013,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Directivo,
# Soto Nieto, Adriana Judith,
# SECRETARIA MUNICIPAL,
# 6,
# Ingeniera en Administración Publica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 4.868.777,
# 3.961.898,
# No tiene,
# No tiene,
# No tiene,
# 01/04/1982,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Soto Villarroel, Javier Alejandro,
# PROFESIONAL DE APOYO A LA DIRECCIÓN DE OBRAS MUNICIPALES,
# 8,
# Arquitecto,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 3.505.318,
# 2.882.337,
# No tiene,
# No tiene,
# No tiene,
# 01/06/2009,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Toledo Toledo, Roberto Carlos,
# AUXILIAR DE J. P. L. DE PTO. VARAS,
# 14,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.385.039,
# 907.321,
# No tiene,
# No tiene,
# No tiene,
# 16/08/2013,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Torres Alvarado, Victor,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 13,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.586.042,
# 1.115.795,
# No tiene,
# No tiene,
# No tiene,
# 01/04/1990,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Torres Castro, Paola Beatriz,
# APOYO ADMINISTRATIVO DEL DEPTO. DE TRÁNSITO Y TRANSPORTE PÚBLICO,
# 15,
# Ingeniera en Administración de Empresas con Mención en Recursos Humanos,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(12)(13),
# Pesos,
# 1.197.680,
# 911.329,
# $17.127 : 6,00hrs,
# No tiene,
# No tiene,
# 01/01/2019,
# Indefinido,
# SEGUN DECRETO N° 2364/2.020 02 HRS. CON RECARGO DE 25%, SEGÚN DECRETO N° 2348/2.020 01 HRS. CON RECARGO DE 25% Y SEGÚN DECRETO N° 2363/2.020 03 HRS. CON RECARGO DE 50% - TRABAJOS EXTRA. NO TIENEN EL CARACTER DE HABITUALES O PERMANENTES,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Profesional,
# Torres Heinz, Yasnina Arlene,
# JEFE DE AUDITORÍA,
# 9,
# Contador Auditor,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 3.015.394,
# 2.434.733,
# No tiene,
# No tiene,
# No tiene,
# 01/10/2015,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Ulloa Navarro, Carlos Rene,
# ADMTVO. J.P.L. DE PTO. VARAS,
# 11,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 2.046.499,
# 1.594.473,
# No tiene,
# No tiene,
# No tiene,
# 07/04/1975,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Uribe Altamirano, Viviana del Carmen,
# ADMTVO. J.P.L. DE PTO. VARAS,
# 13,
# Enseñanza Técnica,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33),
# Pesos,
# 1.614.390,
# 1.156.344,
# No tiene,
# No tiene,
# No tiene,
# 01/01/1997,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Uribe Bastidas, Julieta Yesenia,
# SECRETARIA DE ALCALDÍA,
# 13,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.383.847,
# 1.082.144,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Administrativo,
# Vargas Cardenas, Antonio Segundo,
# RECEPTOR JUDICIAL,
# 11,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82)(33)(50),
# Pesos,
# 1.959.243,
# 1.498.771,
# No tiene,
# No tiene,
# No tiene,
# 10/06/1992,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Técnico,
# Vargas Galindo, Fernando Andrés,
# APOYO TÉCNICO EN SOPORTE INFORMÁTICO,
# 13,
# Técnico de Nivel Superior Analista Programador,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 1.374.386,
# 1.060.090,
# No tiene,
# No tiene,
# No tiene,
# 31/12/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 2020,
#
# Mayo,
# Auxiliar,
# Velásquez Aguilar, José Andrés,
# CONDUCTOR DEPTO. DE OPERACIONES,
# 18,
# Enseñanza Media,
# Región de Los Lagos,
# (131)(07)(132)(51)(75)(76)(78)(37)(82),
# Pesos,
# 890.406,
# 725.529,
# No tiene,
# No tiene,
# No tiene,
# 01/08/2019,
# Indefinido,
# Sin observaciones,
# No publica,
# No informa,
# 98

# %%
 ##No funciona
conn = sqlConnection()
cursorObj = conn.cursor()
query_1 = '''
        CREATE TABLE IF NOT EXISTS region(
            id_region INTEGER PRIMARY KEY AUTOINCREMENT,
            codigo_region INTEGER NOT NULL,
            nombre_region VARCHAR(30) NOT NULL  ); '''

query_2 = '''
        CREATE TABLE IF NOT EXISTS comuna(
            id_comuna INTEGER PRIMARY KEY AUTOINCREMENT,
            codigo_region INTEGER NOT NULL,
            codigo_comuna INTEGER NOT NULL,
            nombre_comuna VARCHAR(30) NOT NULL  );'''

query_3 = '''
        CREATE TABLE IF NOT EXISTS persona(
            id_persona INTEGER PRIMARY KEY AUTOINCREMENT,
            tipo_persona VARCHAR(30) NOT NULL,
            nombre_persona VARCHAR(100) NOT NULL,
            genero_persona CHAR NOT NULL,
            formacion_persona VARCHAR(100) NOT NULL);'''

query_4 = '''
        CREATE TABLE IF NOT EXISTS remuneracion(
            id_remuneracion INTEGER PRIMARY KEY AUTOINCREMENT,
            id_persona INTEGER NOT NULL,
            codigo_comuna INTEGER NOT NULL,
            anio_remuneracion INTEGER NOT NULL,
            mes_remuneracion VARCHAR(15) NOT NULL,
            estamento_remuneracion VARCHAR(100) NOT NULL,
            cargo_remuneracion VARCHAR(100) NOT NULL,
            grado_remuneracion INT NOT NULL,
            asignaciones_remuneracion VARCHAR(50) NOT NULL,
            unidad_monetaria_remuneracion VARCHAR(20) NOT NULL,
            cantidad_bruta_remuneracion VARCHAR(20),
            cantidad_liquida_remuneracion VARCHAR(20),
            horas_extras_diurnas_remuneracion VARCHAR(20) NOT NULL,
            horas_extras_nocturnas_remuneracion VARCHAR(20) NOT NULL,
            horas_extras_festivos_remuneracion VARCHAR(20) NOT NULL,
            fecha_inicio_remuneracion VARCHAR(20) NOT NULL,
            fecha_termino_remuneracion VARCHAR(20) NOT NULL,
            declaracion_patrimonios_remuneracion VARCHAR(100),
            viaticos_remuneracion VARCHAR(100),
            observaciones_remuneracion VARCHAR(200) );'''
sqls = [query_1, query_2, query_3, query_4]

for sql in sqls:
    cursorObj.execute(sql)
    conn.commit()

print('Base de Datos creada con exito.') 
conn.close()

argumentos=(1,LosLagos) ##arreglar aca 
conn = sqlConnection()
cursorObj = conn.cursor()
cursorObj.execute('''
        INSERT INTO region
        (codigo_region, nombre_region) 
        VALUES(?, ?)''', [argumentos])##arreglar aca 
conn.commit()
conn.close() */
