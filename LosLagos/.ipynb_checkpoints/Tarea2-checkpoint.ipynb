# %% [markdown]
# # Tarea 2 : scraper
# **Marcel Carl Esteban Jaure Trujillo**

# %%
import random
from time import sleep
from selenium import webdriver
import pandas as pd
import sqlite3, datetime

# %%
driver = webdriver.Chrome('./chromedriver.exe')
driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU233/PR/PCONT/50090665')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertomontt.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU036/PR/PCONT/50575667')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="chaiten.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU191/PR/PCONT/48516321')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="osorno.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU095/PR/PCONT/50036100')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="futaleufu.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU142/PR/PCONT/44838167')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="llanquihue.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU235/PR/PPLANT/50322569')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertooctay.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()

driver.get('https://www.portaltransparencia.cl/PortalPdT/pdtta/-/ta/MU236/PR/PCONT/50876979')
sleep(random.uniform(3.0,4.0))
datos=driver.find_elements_by_xpath('//td[@class="visualizacion"]')
df="puertovaras.csv"
csv=open(df,"w")
titulor="Año,Mes,Estamento,Nombre completo,Cargo o función,Grado EUS / Cargo con jornada,Calificación profesional o formación,Región,Asignaciones especiales,Unidad monetaria,Remuneración bruta mensualizada,Remuneración líquida mensualizada,Montos y horas extraordinarias diurnas,Montos y horas extraordinarias nocturnas,Montos y horas extraordinarias festivas,Fecha de inicio dd/mm/aa,Fecha de término dd/mm/aa,Declaración de intereses y patrimonio (publicación por buena práctica),Viáticos,Observaciones\n"
csv.write(titulor)

for dato in datos:
    dato= dato.find_element_by_xpath('.//div').text 
    dato= dato+" "
    dato = dato+"\n"
    csv.write(dato) 
    print(dato)
    
csv.close()
# Out:
# 2019
#
# Enero
#
# Auxiliar
#
# AGUILA PAREDES, FRANCISCO AN
#
# CHOFER ASEO Y ORNATO
#
# 18
#
# ED.MEDIA COMPLETA
#
# Región de Los Lagos
#
# (71)(33)
#
# Pesos
#
# 752.452
#
# 661.559
#
# $17.649 : 9,00hrs
#
# No tiene
#
# $75.296 : 32,00hrs
#
# 01/01/2019
#
# 31/12/2019
#
# No publica
#
# No informa
#
# Sin observaciones
#
# 2019
#
# Enero
#
# Auxiliar
#
# AGUILERA LOAIZA, JHONATHAN GA
#
# CHOFER
#
# 18
#
# ED.MEDIA COMPLETA
#
# Región de Los Lagos
#
# (01)
#
# Pesos
#
# 414.304
#
# 344.564
#
# No tiene
#
# No tiene
#
# No tiene
#
# 07/01/2019
#
# 31/12/2019
#
# No publica
#
# No informa
#
# Sin observaciones
#
# 2019
#
# Enero
#
# Profesional
#
# ALMONACID OYARZUN, SONIA GEOVANA
#
# PROFESIONAL DELEGACION ALERCE
#
# 11
#
# ASISTENTE SOCIAL
#
# Región de Los Lagos
#
# (71)(33)
#
# Pesos
#
# 1.533.721
#
# 1.295.863
#
# $41.895 : 9,00hrs
#
# No tiene
#
# $139.650 : 25,00hrs
#
# 01/01/2019
#
# 31/12/2019
#
# No publica
#
# No informa
#
# Sin observaciones
#
# 2019
#
# Enero
#
# ...
